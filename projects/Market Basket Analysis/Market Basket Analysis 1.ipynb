# %% [markdown]
# This example is done using the following url: https://pbpython.com/market-basket-analysis.html

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_excel('Online Retail.xlsx')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)

# %%
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# for i in sorted(df.Country.unique()):
# #     print(i, df[df['Country']==i].shape)
#     if df[df['Country']==i].shape[0]<1000:
#         print(i, df[df['Country']==i].shape)
#         print(df[df['Country']==i]['InvoiceNo'].nunique())

# %% [markdown]
# # Rules for Portugal

# %%
data = df[df['Country']=='Portugal']
print('The number of invoices', data['InvoiceNo'].nunique())
print('The number of lines',data.shape[0])
# Out:
# The number of invoices 58
# The number of lines 1501

# %%
basket = pd.pivot_table(data, index=['InvoiceNo'], columns=['Description'], values=['Quantity'], aggfunc='sum', fill_value=0)

# %%
basket.columns = basket.columns.droplevel()

# %%
basket.drop(['POSTAGE'], inplace=True, axis=1)

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %%
basket_sets = basket.applymap(encode_units)

# %%
# del df
del basket

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True, low_memory=True)

# %%
frequent_itemsets
# Out:
#       support                                           itemsets
# 0    0.120690                      (4 TRADITIONAL SPINNING TOPS)
# 1    0.086207                      (60 TEATIME FAIRY CAKE CASES)
# 2    0.206897                     (BAKING SET 9 PIECE RETROSPOT)
# 3    0.086207                            (BLUE HARMONICA IN BOX)
# 4    0.086207                     (BOX OF VINTAGE JIGSAW BLOCKS)
# ..        ...                                                ...
# 237  0.086207  (LUNCH BAG CARS BLUE, JUMBO SHOPPER VINTAGE RE...
# 238  0.086207  (LUNCH BAG DOLLY GIRL DESIGN, LUNCH BAG RED RE...
# 239  0.086207  (LUNCH BAG RED RETROSPOT, JUMBO SHOPPER VINTAG...
# 240  0.086207  (LUNCH BAG CARS BLUE, JUMBO BAG SCANDINAVIAN B...
# 241  0.086207  (LUNCH BAG CARS BLUE, JUMBO BAG SCANDINAVIAN B...
#
# [242 rows x 2 columns]

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=.1)

# %%
rules[ (rules['lift'] >= 5) &
       (rules['confidence'] >= 0.8) & (rules['conviction'] != np.inf)].sort_values(['confidence','lift'])
# Out:
#                                            antecedents  \
# 20                 (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 240     (LUNCH BAG CARS BLUE, LUNCH BAG PINK POLKADOT)
# 252       (LUNCH BAG SUKI DESIGN, LUNCH BAG CARS BLUE)
# 264  (LUNCH BAG DOLLY GIRL DESIGN, LUNCH BAG RED RE...
# 270  (LUNCH BAG RED RETROSPOT, LUNCH BAG PINK POLKA...
# ..                                                 ...
# 19                    (JUMBO BAG PINK VINTAGE PAISLEY)
# 163  (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG ...
# 166              (JUMBO BAG SCANDINAVIAN BLUE PAISLEY)
# 167                   (JUMBO BAG PINK VINTAGE PAISLEY)
# 227                   (JUMBO BAG PINK VINTAGE PAISLEY)
#
#                                            consequents  antecedent support  \
# 20                    (JUMBO BAG PINK VINTAGE PAISLEY)            0.189655
# 240                   (JUMBO BAG PINK VINTAGE PAISLEY)            0.103448
# 252                   (JUMBO BAG PINK VINTAGE PAISLEY)            0.103448
# 264                   (JUMBO BAG PINK VINTAGE PAISLEY)            0.103448
# 270                   (JUMBO BAG PINK VINTAGE PAISLEY)            0.103448
# ..                                                 ...                 ...
# 19               (JUMBO BAG SCANDINAVIAN BLUE PAISLEY)            0.155172
# 163              (JUMBO BAG SCANDINAVIAN BLUE PAISLEY)            0.155172
# 166  (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG ...            0.155172
# 167  (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG ...            0.155172
# 227  (JUMBO SHOPPER VINTAGE RED PAISLEY, LUNCH BAG ...            0.155172
#
#      consequent support   support  confidence      lift  leverage  conviction
# 20             0.155172  0.155172    0.818182  5.272727  0.125743    4.646552
# 240            0.155172  0.086207    0.833333  5.370370  0.070155    5.068966
# 252            0.155172  0.086207    0.833333  5.370370  0.070155    5.068966
# 264            0.155172  0.086207    0.833333  5.370370  0.070155    5.068966
# 270            0.155172  0.086207    0.833333  5.370370  0.070155    5.068966
# ..                  ...       ...         ...       ...       ...         ...
# 19             0.155172  0.137931    0.888889  5.728395  0.113853    7.603448
# 163            0.155172  0.137931    0.888889  5.728395  0.113853    7.603448
# 166            0.155172  0.137931    0.888889  5.728395  0.113853    7.603448
# 167            0.137931  0.137931    0.888889  6.444444  0.116528    7.758621
# 227            0.137931  0.137931    0.888889  6.444444  0.116528    7.758621
#
# [261 rows x 9 columns]
