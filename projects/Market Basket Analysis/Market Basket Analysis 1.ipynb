# %% [markdown]
# This example is done using the following url: https://pbpython.com/market-basket-analysis.html

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_excel('Online Retail.xlsx')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)

# %%
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# for i in sorted(df.Country.unique()):
# #     print(i, df[df['Country']==i].shape)
#     if df[df['Country']==i].shape[0]<1000:
#         print(i, df[df['Country']==i].shape)
#         print(df[df['Country']==i]['InvoiceNo'].nunique())

# %% [markdown]
# # Rules for Portugal

# %%
data = df[df['Country']=='Portugal']
print('The number of invoices', data['InvoiceNo'].nunique())
print('The number of lines',data.shape[0])
# Out:
# The number of invoices 58
# The number of lines 1501

# %%
basket = pd.pivot_table(data, index=['InvoiceNo'], columns=['Description'], values=['Quantity'], aggfunc='sum', fill_value=0)

# %%
basket.columns = basket.columns.droplevel()

# %%
basket.drop(['POSTAGE'], inplace=True, axis=1)

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %%
basket_sets = basket.applymap(encode_units)
# Out:
# /var/folders/8w/5p2bs93x2xgc8trrh56v3dpc0000gn/T/ipykernel_67114/934781179.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   basket_sets = basket.applymap(encode_units)

# %%
# del df
del basket

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True, low_memory=True)
# Out:
# /Users/utkarshgoyal/Desktop/venv/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
frequent_itemsets.head()
# Out:
#     support                        itemsets
# 0  0.120690   (4 TRADITIONAL SPINNING TOPS)
# 1  0.086207   (60 TEATIME FAIRY CAKE CASES)
# 2  0.206897  (BAKING SET 9 PIECE RETROSPOT)
# 3  0.086207         (BLUE HARMONICA IN BOX)
# 4  0.086207  (BOX OF VINTAGE JIGSAW BLOCKS)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=.1)

# %%
rules[(rules['lift'] >= 5) & (rules['confidence'] >= 0.8) & (rules['conviction'] != np.inf)].sort_values(['confidence','lift'])
# Out:
#                                            antecedents  \
# 20                 (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 242     (LUNCH BAG CARS BLUE, LUNCH BAG PINK POLKADOT)
# 253       (LUNCH BAG SUKI DESIGN, LUNCH BAG CARS BLUE)
# 266  (LUNCH BAG DOLLY GIRL DESIGN, LUNCH BAG RED RE...
# 272  (LUNCH BAG RED RETROSPOT, LUNCH BAG PINK POLKA...
# ..                                                 ...
# 19                    (JUMBO BAG PINK VINTAGE PAISLEY)
# 164  (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG ...
# 165              (JUMBO BAG SCANDINAVIAN BLUE PAISLEY)
# 167                   (JUMBO BAG PINK VINTAGE PAISLEY)
# 226                   (JUMBO BAG PINK VINTAGE PAISLEY)
#
#                                            consequents  antecedent support  \
# 20                    (JUMBO BAG PINK VINTAGE PAISLEY)            0.189655
# 242                   (JUMBO BAG PINK VINTAGE PAISLEY)            0.103448
# 253                   (JUMBO BAG PINK VINTAGE PAISLEY)            0.103448
# 266                   (JUMBO BAG PINK VINTAGE PAISLEY)            0.103448
# 272                   (JUMBO BAG PINK VINTAGE PAISLEY)            0.103448
# ..                                                 ...                 ...
# 19               (JUMBO BAG SCANDINAVIAN BLUE PAISLEY)            0.155172
# 164              (JUMBO BAG SCANDINAVIAN BLUE PAISLEY)            0.155172
# 165  (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG ...            0.155172
# 167  (JUMBO BAG SCANDINAVIAN BLUE PAISLEY, JUMBO SH...            0.155172
# 226  (JUMBO SHOPPER VINTAGE RED PAISLEY, LUNCH BAG ...            0.155172
#
#      consequent support   support  confidence      lift  representativity  \
# 20             0.155172  0.155172    0.818182  5.272727               1.0
# 242            0.155172  0.086207    0.833333  5.370370               1.0
# 253            0.155172  0.086207    0.833333  5.370370               1.0
# 266            0.155172  0.086207    0.833333  5.370370               1.0
# 272            0.155172  0.086207    0.833333  5.370370               1.0
# ..                  ...       ...         ...       ...               ...
# 19             0.155172  0.137931    0.888889  5.728395               1.0
# 164            0.155172  0.137931    0.888889  5.728395               1.0
# 165            0.155172  0.137931    0.888889  5.728395               1.0
# 167            0.137931  0.137931    0.888889  6.444444               1.0
# 226            0.137931  0.137931    0.888889  6.444444               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 20   0.125743    4.646552       1.000000  0.818182   0.784787    0.909091
# 242  0.070155    5.068966       0.907692  0.500000   0.802721    0.694444
# 253  0.070155    5.068966       0.907692  0.500000   0.802721    0.694444
# 266  0.070155    5.068966       0.907692  0.500000   0.802721    0.694444
# 272  0.070155    5.068966       0.907692  0.500000   0.802721    0.694444
# ..        ...         ...            ...       ...        ...         ...
# 19   0.113853    7.603448       0.977041  0.800000   0.868481    0.888889
# 164  0.113853    7.603448       0.977041  0.800000   0.868481    0.888889
# 165  0.113853    7.603448       0.977041  0.800000   0.868481    0.888889
# 167  0.116528    7.758621       1.000000  0.888889   0.871111    0.944444
# 226  0.116528    7.758621       1.000000  0.888889   0.871111    0.944444
#
# [261 rows x 14 columns]
